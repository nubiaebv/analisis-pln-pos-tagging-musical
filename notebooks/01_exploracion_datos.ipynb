# %% [markdown]
# # EDA Basico

# %% [markdown]
# Este notebook realiza un EDA general del dataset **antes** de aplicar técnicas de minería de texto.

# %% [markdown]
# ## Importación de Librerias

# %%
import warnings
from src.utils import path
import pandas as pd
# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Carga de DataSet

# %%
directorio_proyecto = path.obtener_ruta_local()
df = pd.read_csv(directorio_proyecto+'\\data\\raw\\spotify_millsongdata.csv',delimiter = ',',decimal = ".", encoding='utf-8')
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# ## Información General del Dataset

# %%
df.drop('link', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  str
#  1   song    57650 non-null  str
#  2   text    57650 non-null  str
# dtypes: str(3)
# memory usage: 69.9 MB

# %%
df.shape
# Out:
# (57650, 3)

# %%
df.dtypes.value_counts()
# Out:
# str    3
# Name: count, dtype: int64

# %%
df.artist.value_counts()
# Out:
# artist
# Donna Summer        191
# Gordon Lightfoot    189
# Bob Dylan           188
# George Strait       188
# Alabama             187
#                    ...
# Zazie                 2
# U-Kiss                1
# X-Treme               1
# Zed                   1
# Zoe                   1
# Name: count, Length: 643, dtype: int64

# %%
df_describe=df.describe()
df_describe.T
# Out:
#         count unique                                                top freq
# artist  57650    643                                       Donna Summer  191
# song    57650  44824             Have Yourself A Merry Little Christmas   35
# text    57650  57494  Chestnuts roasting on an open fire  \r\nJack F...    6

# %% [markdown]
# ## Análisis de Valores Faltantes

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# text      0
# dtype: int64

# %% [markdown]
# ## Análisis de Duplicados

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Guardar dataset

# %%
df.rename(columns={'artist':'musico','song':'nombre_cancion','text':'letra_cancion'}, inplace=True)
df
# Out:
#              musico         nombre_cancion  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                            letra_cancion
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# ...

# %%
df.to_csv(directorio_proyecto+'\\data\\processed\\corpus_spotify.csv', index=False)
